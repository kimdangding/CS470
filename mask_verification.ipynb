# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdangding/CS470/blob/main/mask_verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import library

# %%
from google.colab import drive
drive.mount('/gdrive')
root = '/gdrive/My Drive'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os
import zipfile
import random
import shutil
import tensorflow as tf
import torch
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from os import getcwd
from os import listdir
import cv2

from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import imutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image  as mpimg
import math

import torchvision
from torchvision import models
import torchvision.transforms as T

from matplotlib.path import Path
import matplotlib.patches as patches

# %% [markdown]
# # 2. load pretrained models

# %% [markdown]
# 2.1. model for detect wearing mask vs don't wearing mask

# %%
new_model=tf.keras.models.load_model('/gdrive/My Drive/Code/face_mask_detection_CNN/saved_new_model')

new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 86, 116, 32)       2432
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 43, 58, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 39, 54, 128)       102528
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 19, 27, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 65664)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 65664)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               8405120
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,510,338
# Trainable params: 8,510,338
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 2.2. model for detect incorrect mask vs no mask

# %%
new_model2=tf.keras.models.load_model('/gdrive/My Drive/Code/face_mask_detection_CNN/class2_model')

new_model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 86, 116, 32)       2432
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 43, 58, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 39, 54, 128)       102528
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 19, 27, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 65664)             0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 65664)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               8405120
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,510,338
# Trainable params: 8,510,338
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Capture test video by frames

# %%
def video2frame(invideofilename, save_path):
    vidcap = cv2.VideoCapture(invideofilename)
    count = 0
    while True:
      success,image = vidcap.read()
      if not success:
          break
      print ('Read a new frame: ', success)
      fname = "{}.jpg".format("{0:05d}".format(count))
      cv2.imwrite(save_path + fname, image) # save frame as JPEG file
      count += 1
    print("{} images are extracted in {}.". format(count, save_path))

invideofilename = '/gdrive/My Drive/demo2.mp4'
save_path = '/gdrive/My Drive/demo_capture2/'
video2frame(invideofilename,save_path)

# %% [markdown]
# # 4. Define various functions for processing the images

# %%
# convert (r, g, b) to color hexcode
def rgb_to_hex(tuple):
    r, g, b = int(tuple[0]), int(tuple[1]), int(tuple[2])
    return '#' + hex(r)[2:].zfill(2) + hex(g)[2:].zfill(2) + hex(b)[2:].zfill(2)

# %%
#Download Model : torchvision.keypoint rcnn model 사용
keypoint_model = models.detection.keypointrcnn_resnet50_fpn(pretrained=True).eval()

def extract_clothes_color(model, img):
    #Image to Tensor
    trf = T.Compose([
        T.ToTensor()
    ])
    
    input_img = trf(img)
    THRESHOLD = 0.95
    
    # cropped_list : list for saving human detection information
    cropped_list = []
    out = model([input_img])[0]

    codes = [
        Path.MOVETO,
        Path.LINETO,
        Path.LINETO
    ]


    # box : list of x, y coordinates of human detected box
    # score : probability of detection to be human
    # keypoints : list of body keypoints
    for box, score, keypoints in zip(out['boxes'], out['scores'], out['keypoints']):
        score = score.detach().numpy()
        if score < THRESHOLD:
            continue
        box = box.detach().numpy()
        keypoints = keypoints.detach().numpy()[:, :2]
        # extract left shoulder color
        left_x = keypoints[5:10:2][0][0].astype(np.int64).item()
        left_y = keypoints[5:10:2][0][1].astype(np.int64).item()
        left_r,left_g,left_b = img.getpixel((left_x, left_y))

        # extract right shoulder color
        right_x = keypoints[6:11:2][0][0].astype(np.int64).item()
        right_y = keypoints[6:11:2][0][1].astype(np.int64).item()
        right_r, right_g, right_b = img.getpixel((right_x, right_y))
        
        # cropped_img = crop original image with human detection box
        cropped_img = np.array(img)
        cropped_img = cropped_img[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
        xy = (int(box[0]), int(box[1]))

        # color : get average color of left, right shoulder
        color = (int((left_r+right_r)/2), int((left_g+right_g)/2), int((left_b+right_b)/2))
        cropped_list.append((cropped_img, xy, color))
    
    return cropped_list
# Out:
# Downloading: "https://download.pytorch.org/models/keypointrcnn_resnet50_fpn_coco-fc266e95.pth" to /root/.cache/torch/hub/checkpoints/keypointrcnn_resnet50_fpn_coco-fc266e95.pth
# HBox(children=(FloatProgress(value=0.0, max=237034793.0), HTML(value='')))

# %%
def extract_mask(img): 
    if img is None:
        return []

    # load pre-trained Haar cascade model in OpenCV for detect eye point
    face_cascade = cv2.CascadeClassifier('/gdrive/My Drive/Code/face_preprocessing/haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('/gdrive/My Drive/Code/face_preprocessing/haarcascade_eye.xml')

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 3)

    # Append each eye point in the detected face
    eye_point = []
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        eyes = eye_cascade.detectMultiScale(roi_gray)
        eyes = eyes[:2]
        for (ex,ey,ew,eh) in eyes:
            xx = ex + ew // 2
            yy = ey + eh // 2
            eye_point.append((x+xx, y+yy))
            r = (ew + eh) // 4

    # Return empty list if there are no detected eyes
    if len(eye_point) < 2:
        return []

    # Set the left and right eyes by comparing the location
    eye1 = eye_point[0]
    eye2 = eye_point[1]
    length = math.sqrt(((eye1[0] - eye2[0]) ** 2) + ((eye1[1] - eye2[1]) ** 2))

    if eye1[0] > eye2[0]:
        right = eye1
        left = eye2
    elif eye1[0] < eye2[0]:
        right = eye2
        left = eye1

    # Rotated the image to fit the eye level
    if left[1] > right[1]:
        angle = math.atan2((right[1]-left[1]), (right[0]-left[0]))
        theta = angle*(180/math.pi);
        rotated = imutils.rotate(img,theta)
    elif left[1] <= right[1]:
        angle = math.atan2((left[1]-right[1]), (right[0]-left[0]))
        theta = angle*(180/math.pi);
        rotated = imutils.rotate(img,-theta)

    # Crop the rotated image by estimated size face
    cropped = rotated[int(left[1] - 0.6 * length):int(left[1] + 1.8 * length), int(left[0] - 0.6 * length):int(right[0] + 0.6 * length)]
    
    if cropped.size == 0:
        return []
    
    # Resize the cropped image by mask region
    resized = cv2.resize(cropped, dsize = (120, 140), interpolation=cv2.INTER_AREA)
    mask_region = resized[50:, :]

    # Return the mask region image and the location of the face region
    return mask_region, (int(left[0] - 0.6 * length), int(left[1] - 0.6 * length), int(left[0] + 1.6 * length), int(left[1] + 1.8 * length))

# %%
# !pip install webcolors
import webcolors
from webcolors import CSS21_HEX_TO_NAMES
# Out:
# Collecting webcolors
#   Downloading https://files.pythonhosted.org/packages/12/05/3350559de9714b202e443a9e6312937341bd5f79f4e4f625744295e7dd17/webcolors-1.11.1-py3-none-any.whl
# Installing collected packages: webcolors
# Successfully installed webcolors-1.11.1

# %%
def closest_colour(requested_colour):
    min_colours = {}
    for key, name in webcolors.CSS21_HEX_TO_NAMES.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_colour[0]) ** 2
        gd = (g_c - requested_colour[1]) ** 2
        bd = (b_c - requested_colour[2]) ** 2
        min_colours[(rd + gd + bd)] = name
    return min_colours[min(min_colours.keys())]

def get_colour_name(requested_colour):
    try:
        color_name = webcolors.rgb_to_name(requested_colour)
    except ValueError:
        color_name = closest_colour(requested_colour)
    return color_name

# %% [markdown]
# # 5. Test our model for captured images and save the results

# %%
for i in range(504):
    # read frames of video.
    img_string = '/gdrive/My Drive/output/mp4_capture/{0:05d}.jpg'.format(i)
    img_org = cv2.imread(img_string)

    print("{0:05d}:".format(i), end = " ")
    try:
        pil_img = Image.fromarray(img_org)
        # get list of information of each person
        cropped_list = extract_clothes_color(keypoint_model, pil_img)
        for (cropped_img, xy, color) in cropped_list:
            color_name = get_colour_name(color)
            print ("color name:", color_name)
            face_img, location = extract_mask(cropped_img)
            face_img = (np.expand_dims(face_img, 0))
            predictions_single=new_model.predict(face_img)
            correctness = np.argmax(predictions_single[0])
            x,y,x2,y2 = location

            # when a person doesn't correctly wear mask
            if correctness == 0:
                predictions_mask_incor = new_model2.predict(face_img)
                correctness_mask_incor = np.argmax(predictions_mask_incor[0])
                # when a person doesn't have mask
                if correctness_mask_incor == 0:
                    cv2.rectangle(img_org, (x + xy[0], y + xy[1]), (x2 + xy[0], y2 + xy[1]), (0, 0, 255), 4)
                    cv2.putText(img_org, "No mask", (x + xy[0], y - 10 + xy[1]), cv2.FONT_HERSHEY_SIMPLEX, 2, color, 3)
                # when a person wear mask incorrectly
                else:
                    cv2.rectangle(img_org, (x + xy[0], y + xy[1]), (x2 + xy[0], y2 + xy[1]), (0, 255, 255), 4)
                    cv2.putText(img_org, "Incorrect mask", (x + xy[0], y - 10 + xy[1]), cv2.FONT_HERSHEY_SIMPLEX, 2, color, 3)
            # when a person wears a mask correctly
            elif correctness == 1:
                cv2.rectangle(img_org, (x + xy[0], y + xy[1]), (x2 + xy[0], y2 + xy[1]), (0, 255, 0), 4)
                cv2.putText(img_org, "Correct mask", (x + xy[0], y - 10 + xy[1]), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
           

    except:
        print("error")
        pass
        
    newname = '/gdrive/My Drive/output/final_capture1/{0:05d}_test.jpg'.format(i)
    cv2.imwrite(newname,img_org)
# Out:
# 00000: color name: navy
# 00001: color name: navy
# 00002: color name: purple
# 00003: color name: purple
# 00004: color name: purple
# 00005: color name: purple
# 00006: color name: purple
# 00007: color name: purple
# 00008: color name: purple
# 00009: color name: purple
# error
# 00010: color name: purple
# error
# 00011: color name: purple
# 00012: color name: purple
# 00013: color name: purple
# 00014: color name: navy
# 00015: color name: gray
# 00016: color name: gray
# 00017: color name: purple
# 00018: color name: maroon
# 00019: color name: maroon
# 00020: color name: gray
# 00021: color name: maroon
# 00022: color name: purple
# 00023: color name: purple
# 00024: color name: maroon
# 00025: color name: maroon
# 00026: color name: gray
# 00027: color name: maroon
# 00028: color name: purple
# 00029: color name: gray
# 00030: color name: purple
# 00031: color name: purple
# 00032: color name: purple
# 00033: color name: gray
# 00034: color name: gray
# 00035: color name: gray
# 00036: color name: gray
# 00037: color name: gray
# 00038: color name: gray
# 00039: color name: gray
# 00040: color name: gray
# 00041: color name: gray
# 00042: color name: purple
# 00043: color name: gray
# 00044: color name: gray
# 00045: color name: gray
# error
# 00046: color name: gray
# 00047: color name: gray
# 00048: color name: purple
# 00049: color name: gray
# 00050: color name: gray
# 00051: color name: gray
# 00052: color name: gray
# 00053: color name: maroon
# 00054: color name: maroon
# 00055: color name: maroon
# 00056: color name: gray
# 00057: color name: maroon
# 00058: color name: maroon
# 00059: color name: maroon
# 00060: color name: maroon
# 00061: color name: purple
# 00062: color name: gray
# 00063: color name: gray
# 00064: color name: gray
# 00065: color name: maroon
# 00066: color name: gray
# 00067: color name: maroon
# 00068: color name: gray
# 00069: color name: gray
# 00070: color name: maroon
# 00071: color name: gray
# 00072: color name: gray
# 00073: color name: gray
# 00074: color name: gray
# 00075: color name: gray
# 00076: color name: gray
# 00077: color name: gray
# 00078: color name: gray
# 00079: color name: gray
# 00080: color name: gray
# 00081: color name: gray
# 00082: color name: gray
# 00083: color name: gray
# 00084: color name: gray
# 00085: color name: gray
# 00086: color name: gray
# 00087: color name: gray
# 00088: color name: gray
# 00089: color name: gray
# 00090: color name: purple
# 00091: color name: gray
# 00092: color name: gray
# 00093: color name: gray
# 00094: color name: purple
# 00095: color name: gray
# 00096: color name: maroon
# 00097: color name: purple
# 00098: color name: gray
# 00099: color name: gray
# 00100: color name: gray
# 00101: color name: gray
# 00102: color name: gray
# 00103: color name: purple
# 00104: color name: gray
# 00105: color name: gray
# 00106: color name: gray
# 00107: color name: gray
# 00108: color name: gray
# 00109: color name: gray
# 00110: color name: gray
# 00111: color name: gray
# 00112: color name: gray
# 00113: color name: gray
# 00114: color name: gray
# 00115: color name: gray
# 00116: color name: gray
# 00117: color name: gray
# 00118: color name: gray
# 00119: color name: gray
# 00120: color name: gray
# 00121: color name: gray
# 00122: color name: gray
# 00123: color name: olive
# 00124: color name: gray
# 00125: color name: gray
# 00126: color name: gray
# 00127: color name: gray
# 00128: color name: gray
# 00129: color name: gray
# 00130: color name: gray
# 00131: color name: gray
# 00132: color name: gray
# 00133: color name: gray
# 00134: color name: gray
# 00135: color name: gray
# 00136: color name: maroon
# 00137: color name: gray
# 00138: color name: olive
# 00139: color name: gray
# 00140: color name: gray
# 00141: color name: gray
# 00142: color name: gray
# 00143: color name: olive
# 00144: color name: maroon
# 00145: color name: maroon
# 00146: color name: maroon
# 00147: color name: maroon
# 00148: color name: maroon
# 00149: color name: maroon
# 00150: color name: maroon
# 00151: color name: maroon
# color name: maroon
# error
# 00152: color name: maroon
# 00153: color name: olive
# 00154: color name: olive
# 00155: color name: maroon
# 00156: color name: maroon
# 00157: color name: maroon
# 00158: color name: olive
# 00159: color name: maroon
# 00160: color name: maroon
# 00161: color name: maroon
# 00162: color name: maroon
# 00163: color name: maroon
# 00164: color name: maroon
# 00165: color name: olive
# 00166: color name: gray
# 00167: color name: gray
# 00168: color name: gray
# 00169: color name: maroon
# 00170: color name: gray
# 00171: color name: gray
# 00172: color name: maroon
# 00173: color name: maroon
# 00174: color name: maroon
# 00175: color name: olive
# 00176: color name: maroon
# 00177: color name: gray
# 00178: color name: olive
# 00179: color name: maroon
# 00180: color name: gray
# 00181: color name: maroon
# 00182: color name: maroon
# 00183: color name: maroon
# 00184: color name: maroon
# 00185: color name: maroon
# 00186: color name: olive
# 00187: color name: maroon
# 00188: color name: maroon
# 00189: color name: maroon
# 00190: color name: maroon
# 00191: color name: maroon
# 00192: color name: gray
# 00193: color name: maroon
# 00194: color name: maroon
# 00195: color name: gray
# 00196: color name: olive
# 00197: color name: olive
# 00198: color name: olive
# 00199: color name: olive
# 00200: color name: olive
# 00201: color name: gray
# 00202: color name: gray
# 00203: color name: gray
# 00204: color name: gray
# 00205: color name: gray
# 00206: color name: gray
# 00207: color name: gray
# 00208: color name: gray
# 00209: color name: gray
# 00210: color name: gray
# 00211: color name: gray
# 00212: color name: gray
# 00213: color name: gray
# 00214: color name: gray
# 00215: color name: gray
# color name: maroon
# error
# 00216: color name: olive
# 00217: color name: olive
# 00218: color name: maroon
# 00219: color name: gray
# 00220: color name: gray
# 00221: color name: silver
# 00222: color name: gray
# 00223: color name: navy
# 00224: color name: purple
# 00225: color name: purple
# 00226: color name: purple
# 00227: color name: purple
# 00228: color name: purple
# 00229: color name: purple
# 00230: color name: purple
# 00231: color name: purple
# 00232: color name: purple
# 00233: color name: purple
# 00234: color name: purple
# 00235: color name: purple
# 00236: color name: purple
# 00237: color name: purple
# 00238: color name: purple
# 00239: color name: gray
# 00240: color name: purple
# 00241: color name: purple
# 00242: color name: purple
# 00243: color name: purple
# 00244: color name: purple
# 00245: color name: purple
# 00246: color name: purple
# 00247: color name: purple
# 00248: color name: purple
# 00249: color name: gray
# 00250: color name: gray
# 00251: color name: gray
# 00252: color name: gray
# 00253: color name: gray
# 00254: color name: olive
# 00255: color name: maroon
# 00256: color name: gray
# 00257: color name: maroon
# 00258: color name: maroon
# 00259: color name: maroon
# 00260: color name: maroon
# 00261: color name: olive
# 00262: color name: maroon
# 00263: color name: maroon
# 00264: color name: maroon
# 00265: color name: maroon
# 00266: color name: olive
# 00267: color name: gray
# 00268: color name: gray
# 00269: color name: gray
# 00270: color name: olive
# 00271: color name: gray
# 00272: color name: gray
# 00273: color name: olive
# 00274: color name: olive
# 00275: color name: maroon
# 00276: color name: maroon
# 00277: color name: maroon
# 00278: color name: maroon
# 00279: color name: maroon
# 00280: color name: maroon
# 00281: color name: maroon
# 00282: color name: black
# 00283: color name: maroon
# 00284: color name: black
# 00285: color name: maroon
# 00286: color name: maroon
# 00287: color name: black
# 00288: color name: black
# 00289: color name: maroon
# 00290: color name: maroon
# 00291: color name: maroon
# 00292: color name: gray
# 00293: color name: gray
# 00294: color name: maroon
# color name: gray
# error
# 00295: color name: maroon
# 00296: color name: maroon
# 00297: color name: olive
# 00298: color name: gray
# 00299: color name: silver
# 00300: color name: gray
# 00301: color name: silver
# 00302: color name: gray
# 00303: color name: gray
# 00304: color name: gray
# 00305: color name: gray
# 00306: color name: gray
# 00307: color name: gray
# 00308: color name: gray
# 00309: color name: gray
# 00310: color name: gray
# 00311: color name: purple
# 00312: color name: gray
# 00313: color name: gray
# 00314: color name: gray
# 00315: color name: gray
# 00316: color name: gray
# 00317: color name: gray
# 00318: color name: gray
# 00319: color name: gray
# 00320: color name: gray
# 00321: color name: gray
# 00322: color name: gray
# 00323: color name: gray
# 00324: color name: gray
# 00325: color name: gray
# 00326: color name: gray
# 00327: color name: gray
# 00328: color name: gray
# 00329: color name: gray
# 00330: color name: gray
# 00331: color name: gray
# 00332: color name: gray
# 00333: color name: gray
# 00334: color name: gray
# 00335: color name: gray
# 00336: color name: gray
# 00337: color name: gray
# 00338: color name: gray
# 00339: color name: gray
# 00340: color name: gray
# 00341: color name: gray
# 00342: color name: gray
# 00343: color name: gray
# 00344: color name: gray
# 00345: color name: gray
# 00346: color name: gray
# 00347: color name: gray
# 00348: color name: gray
# 00349: color name: gray
# 00350: color name: gray
# 00351: color name: gray
# 00352: color name: gray
# 00353: color name: purple
# 00354: color name: gray
# 00355: color name: gray
# 00356: color name: purple
# 00357: color name: purple
# 00358: color name: purple
# 00359: color name: purple
# 00360: color name: gray
# 00361: color name: gray
# 00362: color name: gray
# 00363: color name: gray
# 00364: color name: gray
# 00365: color name: gray
# 00366: color name: gray
# 00367: color name: gray
# 00368: color name: gray
# 00369: color name: gray
# 00370: color name: gray
# 00371: color name: gray
# 00372: color name: gray
# 00373: color name: gray
# 00374: color name: gray
# 00375: color name: gray
# 00376: color name: maroon
# 00377: color name: purple
# 00378: color name: purple
# 00379: color name: gray
# 00380: color name: gray
# 00381: color name: gray
# 00382: color name: teal
# 00383: color name: teal
# 00384: color name: teal
# 00385: color name: gray
# 00386: color name: gray
# 00387: color name: gray
# 00388: color name: gray
# 00389: color name: gray
# 00390: color name: gray
# 00391: color name: gray
# 00392: color name: gray
# 00393: color name: gray
# 00394: color name: gray
# 00395: color name: gray
# 00396: color name: gray
# 00397: color name: gray
# 00398: color name: gray
# 00399: color name: gray
# 00400: color name: purple
# 00401: color name: gray
# color name: maroon
# error
# 00402: color name: gray
# 00403: color name: maroon
# 00404: color name: maroon
# 00405: color name: gray
# 00406: color name: olive
# 00407: color name: olive
# 00408: color name: maroon
# 00409: color name: maroon
# 00410: color name: maroon
# 00411: color name: gray
# error
# 00412: color name: maroon
# color name: maroon
# error
# 00413: color name: black
# color name: gray
# error
# 00414: color name: olive
# color name: maroon
# error
# 00415: color name: maroon
# color name: maroon
# error
# 00416: color name: maroon
# color name: maroon
# error
# 00417: color name: olive
# color name: maroon
# error
# 00418: color name: black
# error
# 00419: color name: black
# error
# 00420: color name: black
# error
# 00421: color name: olive
# error
# 00422: color name: gray
# 00423: color name: gray
# 00424: color name: gray
# 00425: color name: gray
# color name: maroon
# error
# 00426: color name: gray
# color name: maroon
# error
# 00427: color name: maroon
# color name: black
# error
# 00428: color name: gray
# 00429: color name: gray
# color name: black
# error
# 00430: color name: gray
# color name: black
# error
# 00431: color name: gray
# color name: black
# error
# 00432: color name: navy
# 00433: color name: navy
# 00434: color name: gray
# error
# 00435: color name: gray
# error
# 00436: color name: silver
# 00437: color name: gray
# error
# 00438: color name: silver
# 00439: color name: teal
# 00440: color name: gray
# 00441: color name: gray
# 00442: color name: gray
# 00443: color name: gray
# 00444: color name: gray
# 00445: color name: gray
# 00446: color name: gray
# 00447: color name: maroon
# 00448: color name: maroon
# 00449: color name: maroon
# 00450: color name: maroon
# 00451: color name: maroon
# 00452: color name: maroon
# 00453: color name: maroon
# 00454: color name: black
# 00455: color name: black
# 00456: color name: black
# 00457: color name: black
# 00458: color name: black
# 00459: color name: black
# error
# 00460: color name: black
# error
# 00461: color name: black
# error
# 00462: color name: maroon
# error
# 00463: color name: black
# error
# 00464: color name: black
# 00465: color name: black
# 00466: color name: black
# 00467: color name: black
# 00468: color name: black
# 00469: color name: black
# 00470: color name: black
# 00471: color name: black
# 00472: color name: black
# 00473: color name: black
# 00474: color name: black
# 00475: color name: black
# 00476: color name: black
# 00477: color name: black
# 00478: color name: black
# 00479: color name: black
# 00480: color name: black
# 00481: color name: maroon
# 00482: color name: black
# 00483: color name: maroon
# 00484: color name: black
# 00485: color name: black
# 00486: color name: purple
# 00487: color name: black
# 00488: color name: black
# error
# 00489: color name: black
# error
# 00490: color name: black
# error
# 00491: color name: black
# 00492: color name: black
# 00493: color name: black
# 00494: color name: black
# 00495: color name: black
# 00496: color name: black
# 00497: color name: maroon
# 00498: color name: black
# 00499: color name: black
# 00500: color name: black
# 00501: color name: black
# 00502: color name: maroon
# 00503: color name: black

# %% [markdown]
# # 6. Make gif file with result images

# %%
import imageio
import matplotlib.image as mpimg

# %%
path = [f"/gdrive/My Drive/output/final-no-cor/{i}" for i in os.listdir("/gdrive/My Drive/output/final-no-cor/")]
paths = [ cv2.resize(np.array(Image.open(i)),dsize=(0,0),fx=0.5,fy=0.5,interpolation=cv2.INTER_LINEAR) for i in path]
imageio.mimsave('/gdrive/My Drive/output/final-no-cor.gif', paths, fps=25)
